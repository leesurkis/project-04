# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import csv, re
import nltk
import string
from html.parser import HTMLParser
import pickle
import logging

from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
from wordcloud import WordCloud, STOPWORDS , ImageColorGenerator
from sklearn import datasets
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.feature_extraction import text
from sklearn.decomposition import TruncatedSVD, NMF
from gensim import corpora, models, similarities, matutils

# %%
nltk.download('wordnet')
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/leesurkis/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
df = pd.read_csv('tweets_4emotions.csv')

# %%
# df2 = pd.read_csv('text_emotion.csv')

# %%
df = df.iloc[:,0:3]
df
# add feature that looks at profanity using fuzzywuzzy
# Out:
#          ID                                            content  emotion
# 0     10000  How the fu*k! Who the heck! moved my fridge!.....    anger
# 1     10001  So my Indian Uber driver just called someone t...    anger
# 2     10002  @DPD_UK I asked for my parcel to be delivered ...    anger
# 3     10003  so ef whichever butt wipe pulled the fire alar...    anger
# 4     10004  Don't join @BTCare they put the phone down on ...    anger
# 5     10005                                My blood is boiling    anger
# 6     10006  When you've still got a whole season of Wentwo...    anger
# 7     10007  @bt_uk why does tracking show my equipment del...    anger
# 8     10008  @TeamShanny legit why i am so furious with him...    anger
# 9     10009  How is it suppose to work if you do that? Wtf ...    anger
# 10    10010  im so mad about power rangers. im incensed. im...    anger
# 11    10011  Wont use using @mothercareuk @Mothercarehelp a...    anger
# 12    10012  Bitches aggravate like what inspires you to be...    anger
# 13    10013  Why does @dapperlaughs have to come to Glasgow...    anger
# 14    10014                                 Fuking fuming ðŸ˜¤    anger
# 15    10015  Zero help from @ups customer service. Just pus...    anger
# 16    10016  @ArizonaCoyotes not to mention the GRA guy sto...    anger
# 17    10017  I hate my lawn mower. If it had a soul, I'd co...    anger
# 18    10018  why are people so offended by kendall he ends ...    anger
# 19    10019  I'm about to block everyone everywhere posting...    anger
# 20    10020  Making my buddy cry !! Bitch wait for revenge ...    anger
# 21    10021  Bes! You don't just tell a true blooded hoopju...    anger
# 22    10022  I got a NO RESPONSE again from an #irate custo...    anger
# 23    10023  Tasers immobilize, if you taser someone why th...    anger
# 24    10024  @LeKingCoq @MistaAggy @GiovanniiDC The way my ...    anger
# 25    10025    Actually fuming I have nothing to wear Saturday    anger
# 26    10026  .@DIVAmagazine than straight people. Even the ...    anger
# 27    10027             Bloody parking ticket ðŸ˜’ðŸ’¸ #fuming    anger
# 28    10028  You ever just find that the people around you ...    anger
# 29    10029  I get so angry at people that don't know that ...    anger
# ...     ...                                                ...      ...
# 3583  40756  Guys! Read my #fanfiction if you like #lost an...  sadness
# 3584  40757  @m_giacchino will this be aired on radio or fi...  sadness
# 3585  40758  Very long day. Thank goodness for Bake Off to ...  sadness
# 3586  40759  TONIGHT - Fulford Arms, York \nTOMORROW - Bank...  sadness
# 3587  40760  I'm so proud he understands this, he shows lov...  sadness
# 3588  40761                                          blues bar  sadness
# 3589  40762  @GOP she's ahead in the polls &amp; after Trum...  sadness
# 3590  40763  @urbaneprofessor roast them. Then risotto with...  sadness
# 3591  40764  Happiness is always there. You just have to ch...  sadness
# 3592  40765  Good morning chirpy #SpringEquinox and your pe...  sadness
# 3593  40766  also who has amazon prime that would like to h...  sadness
# 3594  40767  I added Paul Walker on Xbox but he just spends...  sadness
# 3595  40768  Nice to see Balotelli back to his best, good p...  sadness
# 3596  40769  @KatieBurnett ha freshers blues would love to ...  sadness
# 3597  40770  What do you get when you cross an #apple tree ...  sadness
# 3598  40771  Please bear with me, I'm not Twitter savvyðŸ˜...  sadness
# 3599  40772  @RiRiMathew even when we're fighting I'm laugh...  sadness
# 3600  40773  @SquidWasTaken Pfft- Yeye, i'm a sucker for br...  sadness
# 3601  40774  Never a dull moment when talking to Nell ðŸ˜‚ð...  sadness
# 3602  40775                             Never dull moment here  sadness
# 3603  40776  #picoftheday : How...why... Really... !!\n    ...  sadness
# 3604  40777  @EBled2 Great to have you as our tournament ch...  sadness
# 3605  40778  @DarbyHogle the red one would look super prett...  sadness
# 3606  40779  @PottzGaming hmu need players for lans next ye...  sadness
# 3607  40780  #FF @ElizaNealsRocks Love &amp; support, alway...  sadness
# 3608  40781  @VivienLloyd Thank you so much! Just home - st...  sadness
# 3609  40782  Just put the winter duvet on â˜ƒï¸â„ï¸ðŸŒ¬â...  sadness
# 3610  40783  @SilkInSide @TommyJoeRatliff that's so pretty!...  sadness
# 3611  40784  @BluesfestByron second artist announcement loo...  sadness
# 3612  40785  I can literally eat creamy pesto pasta topped ...  sadness
#
# [3613 rows x 3 columns]

# %%
df = df[df.ID != 30726]

# %%
# df2.drop(columns=['author'], inplace=True)

# %%
# df3 = df2[['tweet_id', 'content', 'sentiment']]

# %%
# df3 = df3.rename(columns={'tweet_id': 'ID'})

# %%
# df3 = df3.rename(columns={'sentiment': 'emotion'})

# %%
# df3

# %%
# df = df.append(df3, ignore_index=True)

# %%
# df.emotion.value_counts()

# %%
df.drop(df[df['content'].str.contains("broadcast by")].index, inplace=True)

# %%
df.shape
# Out:
# (3558, 3)

# %%
ax = sns.countplot(x="emotion", data=df)
sns.set(rc={'figure.figsize':(15.7,12.27)})

# %%
# replacing all punctuation apart from @ mentions with '' and making lower case
df['regex'] = df['content'].apply(lambda x: re.sub("[^@# a-z]","",x.lower()))
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# removing twitter handles
df['remove_mentions'] = df['regex'].apply(lambda x: ' '.join(re.sub("(@[A-Za-z0-9]+)|(#[A-Za-z0-9]+)","",x).split()))
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# replacing some slang
df['no_slang'] = df['remove_mentions'].apply(lambda x: re.sub('(ahhh|ahhhh|ahhhh|ahhhhh|ahhhhhh|ahhhhhh)',
                            'ahh',x)).apply(lambda x: re.sub('(hahaha|hahahaha|hahahahaha)','haha'
                                ,x)).apply(lambda x: re.sub('(awww|awwww|awwwww|awwwwww|awwwwwww|awwwwwwww)','aww',x))
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
df.head()
# Out:
#       ID                                            content emotion  \
# 0  10000  How the fu*k! Who the heck! moved my fridge!.....   anger
# 1  10001  So my Indian Uber driver just called someone t...   anger
# 2  10002  @DPD_UK I asked for my parcel to be delivered ...   anger
# 3  10003  so ef whichever butt wipe pulled the fire alar...   anger
# 4  10004  Don't join @BTCare they put the phone down on ...   anger
#
#                                                regex  \
# 0  how the fuk who the heck moved my fridge shoul...
# 1  so my indian uber driver just called someone t...
# 2  @dpduk i asked for my parcel to be delivered t...
# 3  so ef whichever butt wipe pulled the fire alar...
# 4  dont join @btcare they put the phone down on y...
#
#                                      remove_mentions  \
# 0  how the fuk who the heck moved my fridge shoul...
# 1  so my indian uber driver just called someone t...
# 2  i asked for my parcel to be delivered to a pic...
# 3  so ef whichever butt wipe pulled the fire alar...
# 4  dont join they put the phone down on you talk ...
#
#                                             no_slang
# 0  how the fuk who the heck moved my fridge shoul...
# 1  so my indian uber driver just called someone t...
# 2  i asked for my parcel to be delivered to a pic...
# 3  so ef whichever butt wipe pulled the fire alar...
# 4  dont join they put the phone down on you talk ...

# %%
# my own replacement of slang words

df['shorthand'] = df['no_slang'].str.replace(' bc ', ' because ').str.replace(' u ', 
                                ' you ').str.replace(' bf ', ' boyfriend ').str.replace(' gf ', ' girlfriend ').str.replace(' nyt ', 
                                ' night ').str.replace(' ima ', ' i am going to ').str.replace(' wut ', ' what ').str.replace(' wud ', 
                                ' would ').str.replace(' n ', ' and ').str.replace(' fuk ', ' fuck ').str.replace(' gd ', 
                                ' good ').str.replace(' nite ', ' night ').str.replace(' hubs ', ' husband ').str.replace(' dat ', 
                                ' that ').str.replace(' don ', ' ').str.replace(' amp ', ' ').str.replace(' fuking ', 
                                ' fucking ').str.replace(' fuked ', ' fucked ')
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
# look at particular emotions
# test = df.loc[df['emotion'] == 'sadness']
# test

# %%
# remove words of up to 3 characters

df['shorthand'] = df['shorthand'].apply(lambda x: re.sub(r'\b\w{1,2}\b', '', x))
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df.head()
# Out:
#       ID                                            content emotion  \
# 0  10000  How the fu*k! Who the heck! moved my fridge!.....   anger
# 1  10001  So my Indian Uber driver just called someone t...   anger
# 2  10002  @DPD_UK I asked for my parcel to be delivered ...   anger
# 3  10003  so ef whichever butt wipe pulled the fire alar...   anger
# 4  10004  Don't join @BTCare they put the phone down on ...   anger
#
#                                                regex  \
# 0  how the fuk who the heck moved my fridge shoul...
# 1  so my indian uber driver just called someone t...
# 2  @dpduk i asked for my parcel to be delivered t...
# 3  so ef whichever butt wipe pulled the fire alar...
# 4  dont join @btcare they put the phone down on y...
#
#                                      remove_mentions  \
# 0  how the fuk who the heck moved my fridge shoul...
# 1  so my indian uber driver just called someone t...
# 2  i asked for my parcel to be delivered to a pic...
# 3  so ef whichever butt wipe pulled the fire alar...
# 4  dont join they put the phone down on you talk ...
#
#                                             no_slang  \
# 0  how the fuk who the heck moved my fridge shoul...
# 1  so my indian uber driver just called someone t...
# 2  i asked for my parcel to be delivered to a pic...
# 3  so ef whichever butt wipe pulled the fire alar...
# 4  dont join they put the phone down on you talk ...
#
#                                            shorthand
# 0  how the fuck who the heck moved  fridge should...
# 1    indian uber driver just called someone the a...
# 2   asked for  parcel   delivered   pick  store n...
# 3    whichever butt wipe pulled the fire alarm  d...
# 4  dont join they put the phone down  you talk ov...

# %%
# remove stop words
additional_stop_words = ['dont','get','got','did','know','really','tell','work','tonight','going','like','want','go','gbbo','make','day','say','do','let','think','just']
stop_words = text.ENGLISH_STOP_WORDS.union(additional_stop_words)
df['no_stop_words'] = df['shorthand'].apply(lambda x: " ".join([word for word in x.split(" ") if word not in stop_words]))
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %% [markdown]
# ### Lemmatization

# %%
lmtzr = WordNetLemmatizer()
df['stemmed'] = df['no_stop_words'].apply(lambda x: ' '.join([lmtzr.lemmatize(word, 'v') for word in x.split() ]))
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df.head(20)
# Out:
#        ID                                            content emotion  \
# 0   10000  How the fu*k! Who the heck! moved my fridge!.....   anger
# 1   10001  So my Indian Uber driver just called someone t...   anger
# 2   10002  @DPD_UK I asked for my parcel to be delivered ...   anger
# 3   10003  so ef whichever butt wipe pulled the fire alar...   anger
# 4   10004  Don't join @BTCare they put the phone down on ...   anger
# 5   10005                                My blood is boiling   anger
# 6   10006  When you've still got a whole season of Wentwo...   anger
# 7   10007  @bt_uk why does tracking show my equipment del...   anger
# 8   10008  @TeamShanny legit why i am so furious with him...   anger
# 9   10009  How is it suppose to work if you do that? Wtf ...   anger
# 10  10010  im so mad about power rangers. im incensed. im...   anger
# 11  10011  Wont use using @mothercareuk @Mothercarehelp a...   anger
# 12  10012  Bitches aggravate like what inspires you to be...   anger
# 13  10013  Why does @dapperlaughs have to come to Glasgow...   anger
# 14  10014                                 Fuking fuming ðŸ˜¤   anger
# 15  10015  Zero help from @ups customer service. Just pus...   anger
# 16  10016  @ArizonaCoyotes not to mention the GRA guy sto...   anger
# 17  10017  I hate my lawn mower. If it had a soul, I'd co...   anger
# 18  10018  why are people so offended by kendall he ends ...   anger
# 19  10019  I'm about to block everyone everywhere posting...   anger
#
#                                                 regex  \
# 0   how the fuk who the heck moved my fridge shoul...
# 1   so my indian uber driver just called someone t...
# 2   @dpduk i asked for my parcel to be delivered t...
# 3   so ef whichever butt wipe pulled the fire alar...
# 4   dont join @btcare they put the phone down on y...
# 5                                 my blood is boiling
# 6   when youve still got a whole season of wentwor...
# 7   @btuk why does tracking show my equipment deli...
# 8   @teamshanny legit why i am so furious with him...
# 9   how is it suppose to work if you do that wtf d...
# 10  im so mad about power rangers im incensed im f...
# 11  wont use using @mothercareuk @mothercarehelp a...
# 12  bitches aggravate like what inspires you to be...
# 13  why does @dapperlaughs have to come to glasgow...
# 14                                     fuking fuming
# 15  zero help from @ups customer service just push...
# 16  @arizonacoyotes not to mention the gra guy sto...
# 17  i hate my lawn mower if it had a soul id conde...
# 18  why are people so offended by kendall he ends ...
# 19  im about to block everyone everywhere posting ...
#
#                                       remove_mentions  \
# 0   how the fuk who the heck moved my fridge shoul...
# 1   so my indian uber driver just called someone t...
# 2   i asked for my parcel to be delivered to a pic...
# 3   so ef whichever butt wipe pulled the fire alar...
# 4   dont join they put the phone down on you talk ...
# 5                                 my blood is boiling
# 6   when youve still got a whole season of wentwor...
# 7   why does tracking show my equipment delivered ...
# 8   legit why i am so furious with him people are ...
# 9   how is it suppose to work if you do that wtf d...
# 10  im so mad about power rangers im incensed im f...
# 11  wont use using again these guys cant get nothi...
# 12  bitches aggravate like what inspires you to be...
# 13  why does have to come to glasgow on a night i ...
# 14                                      fuking fuming
# 15  zero help from customer service just pushing t...
# 16  not to mention the gra guy stops me but lets t...
# 17  i hate my lawn mower if it had a soul id conde...
# 18  why are people so offended by kendall he ends ...
# 19  im about to block everyone everywhere posting ...
#
#                                              no_slang  \
# 0   how the fuk who the heck moved my fridge shoul...
# 1   so my indian uber driver just called someone t...
# 2   i asked for my parcel to be delivered to a pic...
# 3   so ef whichever butt wipe pulled the fire alar...
# 4   dont join they put the phone down on you talk ...
# 5                                 my blood is boiling
# 6   when youve still got a whole season of wentwor...
# 7   why does tracking show my equipment delivered ...
# 8   legit why i am so furious with him people are ...
# 9   how is it suppose to work if you do that wtf d...
# 10  im so mad about power rangers im incensed im f...
# 11  wont use using again these guys cant get nothi...
# 12  bitches aggravate like what inspires you to be...
# 13  why does have to come to glasgow on a night i ...
# 14                                      fuking fuming
# 15  zero help from customer service just pushing t...
# 16  not to mention the gra guy stops me but lets t...
# 17  i hate my lawn mower if it had a soul id conde...
# 18  why are people so offended by kendall he ends ...
# 19  im about to block everyone everywhere posting ...
#
#                                             shorthand  \
# 0   how the fuck who the heck moved  fridge should...
# 1     indian uber driver just called someone the a...
# 2    asked for  parcel   delivered   pick  store n...
# 3     whichever butt wipe pulled the fire alarm  d...
# 4   dont join they put the phone down  you talk ov...
# 5                                      blood  boiling
# 6   when youve still got  whole season  wentworth ...
# 7   why does tracking show  equipment delivered wh...
# 8   legit why    furious with him people are such ...
# 9   how   suppose  work  you  that wtf dude thanks...
# 10         mad about power rangers  incensed  furious
# 11  wont use using again these guys cant get nothi...
# 12  bitches aggravate like what inspires you   the...
# 13  why does have  come  glasgow   night   working...
# 14                                      fuking fuming
# 15  zero help from customer service just pushing t...
# 16  not  mention the gra guy stops  but lets the p...
# 17   hate  lawn mower   had  soul  condemn   the f...
# 18  why are people  offended  kendall  ends photo ...
# 19   about  block everyone everywhere posting abou...
#
#                                         no_stop_words  \
# 0     fuck heck moved  fridge  knock landlord door ##
# 1     indian uber driver called word   wasnt   mov...
# 2    asked  parcel   delivered   pick  store  address
# 3     whichever butt wipe pulled alarm  davis  sou...
# 4   join phone  talk rude taking money   acc willy...
# 5                                      blood  boiling
# 6   youve  season  wentworth  watch  stupid cunt  ...
# 7   does tracking  equipment delivered  wasnt   se...
# 8              legit    furious people fucking idiots
# 9                 suppose    wtf dude thanks pissing
# 10               mad power rangers  incensed  furious
# 11                          wont use using guys right
# 12  bitches aggravate inspires   biggest cunt know...
# 13  does  come  glasgow   night   working   fuckin...
# 14                                      fuking fuming
# 15  zero help customer service pushing buck forth ...
# 16   mention gra guy stops  lets ppl     wtf  bloo...
# 17   hate  lawn mower    soul  condemn   fiery pit...
# 18  people  offended  kendall  ends photo shoot se...
# 19       block posting storm   aware  damn rain  quit
#
#                                               stemmed
# 0        fuck heck move fridge knock landlord door ##
# 1   indian uber driver call word wasnt move vehicl...
# 2               ask parcel deliver pick store address
# 3   whichever butt wipe pull alarm davis sound asl...
# 4      join phone talk rude take money acc willynilly
# 5                                          blood boil
# 6       youve season wentworth watch stupid cunt ruin
# 7   do track equipment deliver wasnt service sudde...
# 8                    legit furious people fuck idiots
# 9                         suppose wtf dude thank piss
# 10                  mad power rangers incense furious
# 11                             wont use use guy right
# 12  bitch aggravate inspire biggest cunt know man ...
# 13  do come glasgow night work fuck gutted wait ap...
# 14                                        fuking fume
# 15  zero help customer service push buck forth pro...
# 16        mention gra guy stop let ppl wtf blood boil
# 17        hate lawn mower soul condemn fiery pit hell
# 18  people offend kendall end photo shoot seriousl...
# 19              block post storm aware damn rain quit

# %%
# word cloud

# ang_df = df.loc[df['emotion'] == 'anger']
# joy_df = df.loc[df['emotion'] == 'joy']
# fear_df = df.loc[df['emotion'] == 'fear']
# sad_df = df.loc[df['emotion'] == 'sadness']

# %%
# Tweet_a = " ".join(review for review in ang_df.stemmed)
# Tweet_f = " ".join(review for review in fear_df.stemmed)
# Tweet_j = " ".join(review for review in joy_df.stemmed)
# Tweet_s = " ".join(review for review in sad_df.stemmed)
# fig, ax = plt.subplots(4, 1, figsize  = (30,30))

# # Create and generate a word cloud image:
# wordcloud_a = WordCloud(max_font_size=50, max_words=100, background_color="white").generate(Tweet_a)
# wordcloud_f = WordCloud(max_font_size=50, max_words=100, background_color="white").generate(Tweet_f)
# wordcloud_j = WordCloud(max_font_size=50, max_words=100, background_color="white").generate(Tweet_j)
# wordcloud_s = WordCloud(max_font_size=50, max_words=100, background_color="white").generate(Tweet_s)

# # Display the generated image:
# ax[0].imshow(wordcloud_a, interpolation='bilinear')
# ax[0].set_title('Anger Words', fontsize=30)
# ax[0].axis('off')
# ax[1].imshow(wordcloud_f, interpolation='bilinear')
# ax[1].set_title('Fear Words',fontsize=30)
# ax[1].axis('off')
# ax[2].imshow(wordcloud_j, interpolation='bilinear')
# ax[2].set_title('Joy Words',fontsize=30)
# ax[2].axis('off')
# ax[3].imshow(wordcloud_s, interpolation='bilinear')
# ax[3].set_title('Sadness Words',fontsize=30)
# ax[3].axis('off')

# %%
additional_stop_words = ['today', 'time','dont','get','way','ive','quotesoup', 'youre','got','did','know','really','tell','work','tonight','going','like','want','go','gbbo','make','day','say','do','let','think','just']
stop_words = text.ENGLISH_STOP_WORDS.union(additional_stop_words)
df['stemmed'] = df['stemmed'].apply(lambda x: " ".join([word for word in x.split(" ") if word not in stop_words]))
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df.to_pickle('more_tweet_data.pkl')
